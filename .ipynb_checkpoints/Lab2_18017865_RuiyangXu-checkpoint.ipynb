# %%
##导入用于数据操作的库
import numpy as np ##导入线性代数
import pandas as pd  ##处理数据，进行csv类型文件的I/O
##导入用于数据可视化的库
import matplotlib.pyplot as plt
"""
Seaborn其实是在matplotlib的基础上进行了更高级的API封装，
从而使得作图更加容易，在大多数情况下使用seaborn就能做出很具有吸引力的图
seaborn库中存有大量的图表类型，kdeplot( )密度曲线图，箱型图 boxplot( )，联合分布jointplot( )，热点图heatmap( ) 
线型图lineplot（），条状图barplot（）等等
"""
import seaborn as sns
# %matplotlib inline
##读取CSV类型文件到DataFrame
NZ_Rain = pd.read_csv("Rainfall_Data.csv")
NZ_Rain.head()
NZ_Rain.describe()
# Out:
#        agent_number  precipitation         lat         lon      anomaly
# count    420.000000     420.000000  420.000000  420.000000   420.000000
# mean    5656.933333     548.462619  -40.898424  173.396331    18.728770
# std     7568.717254     730.971909    3.182839    2.792184   198.265942
# min     1056.000000      48.000000  -46.417410  167.924060 -1083.426667
# 25%     2112.000000     205.550000  -44.002000  170.984280   -50.329167
# 50%     3812.000000     307.500000  -40.583500  174.273910     8.588333
# 75%     5086.000000     631.900000  -38.658600  175.662830    69.193333
# max    37662.000000    8680.300000  -35.183000  177.985100  2177.740000

# %%
plt.figure(figsize = (20,10))
plt.title("New Zealand anomaly per participation")
sns.scatterplot(data = NZ_Rain, x = "anomaly", y = "precipitation")
# Out:
# <AxesSubplot:title={'center':'New Zealand anomaly per participation'}, xlabel='anomaly', ylabel='precipitation'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")
import gc
from datetime import date,datetime

today = datetime.now()
today_str = "%s %d, %d" % (date.today().strftime("%b"), today.day, today.year)
yesterday_str = "%s %d, %d" % (date.today().strftime("%b"), today.day - 1, today.year)

df = pd.read_csv("covid_stats.csv")

# %%
#创建一个dataframe，使用groupby()函数以大洲名称进行分类，并且使用drop()函数抛弃all 所在的行
continent_df = df.groupby('Continent').sum().drop('All')
continent_df = continent_df.reset_index()
continent_df = pd.DataFrame(continent_df)
#number of total cases
cases_vis_list = ['Total Cases', 'Active Cases', 'New Cases', 'Serious/Critical', 'Tot Cases/1M'] 
#number of total deaths
deaths_vis_list = ['Total Deaths', 'New Deaths', 'Deaths/1M']
#number of total recovered
recovered_vis_list = ['Total Recovered', 'New Recovered']
#number of total tests
tests_vis_list = ['Total Tests', 'Tests/1M']
essentials = [['Total Cases', 'Active Cases', 'New Cases'], 
              ['Total Deaths', 'New Deaths'], 
              ['Total Recovered', 'New Recovered']]
    
def continent_visualization(vis_list):
    for label in vis_list:
        c_df = continent_df[['Continent', label]]
        c_df['Percentage'] = np.round(100 * c_df[label] / np.sum(c_df[label]), 2)
        c_df['Virus'] = ['COVID-19' for i in range(len(c_df))]
        fig = px.bar(c_df, x = 'Virus', y = 'Percentage', color = 'Continent', hover_data=[label])
        fig.update_layout(title={'text': f"{label} at the end of {yesterday_str}", 'x': 0.5,
                                 'xanchor': 'center', 'font': {'size': 20}}, 
                                  yaxis_title="Percentage", xaxis_title="")
        fig.show()
continent_visualization(tests_vis_list)
continent_visualization(deaths_vis_list)
gc.collect()
# Out:
# <div>                            <div id="83ec0c8e-69b5-42f1-866a-0e93697f50e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83ec0c8e-69b5-42f1-866a-0e93697f50e7")) {                    Plotly.newPlot(                        "83ec0c8e-69b5-42f1-866a-0e93697f50e7",                        [{"alignmentgroup":"True","customdata":[[94422610]],"hovertemplate":"Continent=Africa<br>Virus=%{x}<br>Percentage=%{y}<br>Total Tests=%{customdata[0]}<extra></extra>","legendgroup":"Africa","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["COVID-19"],"xaxis":"x","y":[1.7],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[1722709424]],"hovertempl
# ...

# %%
df = df.drop([len(df)-1])
country_df = df.drop([0])
country_new_case = country_df.columns[3:4] ##定义列表中的第4列 new case 就是每日增长数值 如果是后 一列 则是[4:5]
fig = go.Figure()

country_num = 0
for i in country_df.index:
    if country_num < 7: #数值最高的7个国家
        fig.add_trace(go.Bar( name=country_df['Country'][i], x= country_new_case, y=country_df.loc[i][3:4]))
    else:
        break
    country_num += 1
fig.update_layout(title={'text': f'{ 7} Countries with Most Increase COVID Cases on %s' % yesterday_str, 
                         'x': 0.5,'xanchor': 'center', 
                         'font': {'size': 20}}, yaxis_title = "Number", yaxis_type = "log", xaxis_tickangle = -90)

fig.show()

gc.collect()
# Out:
# <div>                            <div id="ba933940-4176-4d09-bfe3-a900b4b65acb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba933940-4176-4d09-bfe3-a900b4b65acb")) {                    Plotly.newPlot(                        "ba933940-4176-4d09-bfe3-a900b4b65acb",                        [{"name":"USA","x":["New Cases"],"y":[80842.0],"type":"bar"},{"name":"India","x":["New Cases"],"y":[27409.0],"type":"bar"},{"name":"Brazil","x":["New Cases"],"y":[58100.0],"type":"bar"},{"name":"France","x":["New Cases"],"y":[26475.0],"type":"bar"},{"name":"UK","x":["New Cases"],"y":[41560.0],"type":"bar"},{"name":"Russia","x":["New Cases"],"y":[180456.0],"type":"bar"},{"name":"Turkey","x":["New Cases"],"y":[76632.0],"type":"bar"}],                        {"templa
# ...

# %%
#传递列表中1到14列的所有数据到country_labels变量
country_labels = country_df.columns[1:14]
def country_visualization(continent):
    buttons_list = []
    base_list = [False for i in range(len(country_df))]
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        tmp_list = base_list.copy()
        tmp_list[c] = True
        c += 1
        buttons_list.append(dict(
            args = [{"visible": tmp_list}],
            label = country_df.loc[i]['Country'],method="update"
        ))
    fig = go.Figure()
    c = 0
    for i in country_df.index:
        if country_df.loc[i]['Continent'] != continent:
            continue
        fig.add_trace(go.Bar(name = country_df.loc[i]['Country'], x=country_labels, y=country_df.loc[i][1:14], visible = False 
                             if c != 0 
                             else 
                             True)
                     )
        c += 1
        fig.update_layout(
            updatemenus = [
                dict(
                    buttons=buttons_list,
                    direction="down",
                    pad={"r": 10, "t": 10},
                    showactive=True,
                    x=0.1,
                    xanchor="left",
                    y=1.1,
                    yanchor="top"
                ),
            ] 
        ) 
    fig.update_layout(title={'text': '%s COVID-19 Cases Search on %s' % (continent, yesterday_str), 
                             'x': 0.5,'xanchor': 'center', 'font': {'size': 20}}, yaxis_type="log", xaxis_tickangle=-90)
    fig.show()
    
country_visualization('Australia/Oceania')
country_visualization('Australia/Oceania')

gc.collect()
# Out:
# <div>                            <div id="a8cff005-1e2f-49b8-8148-f5eae846ce4c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8cff005-1e2f-49b8-8148-f5eae846ce4c")) {                    Plotly.newPlot(                        "a8cff005-1e2f-49b8-8148-f5eae846ce4c",                        [{"name":"Australia","visible":true,"x":["Country","Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Recovered","Active Cases","Serious/Critical","Tot Cases/1M","Deaths/1M","Total Tests","Tests/1M"],"y":["Australia",2921698,19779.0,4618,25.0,2745617,24166.0,171463,231,112464.0,178.0,62347100,2399906],"type":"bar"},{"name":"Fiji","visible":false,"x":["Country","Total Cases","New Cases","Total Deaths","New Deaths","Total Recovered","New Re
# ...
