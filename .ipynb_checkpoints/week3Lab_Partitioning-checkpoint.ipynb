# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df_wine = pd.read_csv('https://archive.ics.uci.edu/' 
                      'ml/machine-learning-databases/' 
                      'wine/wine.data', header = None) 

df_wine.columns = ['Class label', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash', 'Magnesium', 
                   'Total phenols', 'Flavanoids', 'Nonflavanoid phenols', 'Proanthocyanins', 
                   'Color intensity', 'Hue', 'OD280/OD315 of diluted wines', 'Proline']

df_wine.filter(['Class label', 'Alcohol', 'Flavanoids', 
                'Color intensity', 'OD280/OD315 of diluted wines', 'Proline'])
# Out:
#      Class label  Alcohol  Flavanoids  Color intensity  OD280/OD315 of diluted wines  Proline
# 0              1    14.23        3.06             5.64                          3.92     1065
# 1              1    13.20        2.76             4.38                          3.40     1050
# 2              1    13.16        3.24             5.68                          3.17     1185
# 3              1    14.37        3.49             7.80                          3.45     1480
# 4              1    13.24        2.69             4.32                          2.93      735
# ..           ...      ...         ...              ...                           ...      ...
# 173            3    13.71        0.61             7.70                          1.74      740
# 174            3    13.40        0.75             7.30                          1.56      750
# 175            3    13.27        0.69            10.20                          1.56      835
# 176            3    13.17        0.68             9.30                          1.62      840
# 177            3    14.13        0.76             9.20                          1.60      560
#
# [178 rows x 6 columns]

# %%
#TO DO 3
Test_set = df_wine.sample(frac=0.3)
Test_set = Test_set.sort_values(by = ['Class label', 'Alcohol'])
print(Test_set)
# Out:
#      Class label  Alcohol  Malic acid   Ash  ...  Color intensity    Hue  OD280/OD315 of diluted wines  Proline
# 44             1    13.05        1.77  2.10  ...             5.04  0.880                          3.35      885
# 25             1    13.05        2.05  3.22  ...             3.58  1.130                          3.20      830
# 38             1    13.07        1.50  2.10  ...             3.70  1.180                          2.69     1020
# 4              1    13.24        2.59  2.87  ...             4.32  1.040                          2.93      735
# 27             1    13.30        1.72  2.14  ...             3.95  1.020                          2.77     1285
# 32             1    13.68        1.83  2.36  ...             3.84  1.230                          2.87      990
# 22             1    13.71        1.86  2.36  ...             3.80  1.110                          4.00     1035
# 51             1    13.83        1.65  2.60  ...             5.60  1.240                          3.37     1265
# 42             1    13.88        1.89  2.59  ...             5.43  0.880                          3.56     1095
# 47             1    13.90        1.68  2.12  ...             6.10  0.910                          3.33      985
# 20             1    14.06        1.63  2.28  ...             5.65  1.090                          3.71      780
# 48             1    14.10        2.02  2.40  ...             6.20  1.070                          2.75     1060
# 5              1    14.20        1.76  2.45  ...             6.75  1.050                          2.85     1450
# 39             1    14.22        3.99  2.51  ...             5.10  0.890                          3.53      760
# 0              1    14.23        1.71  2.43  ...             5.64  1.040                          3.92     1065
# 16             1    14.30        1.92  2.72  ...             6.20  1.070                          2.65     1280
# 14             1    14.38        1.87  2.38  ...             7.50  1.200                          3.00     1547
# 120            2    11.45        2.40  2.42  ...             3.25  0.800                          3.39      625
# 121            2    11.56        2.05  3.23  ...             6.00  0.930                          3.69      465
# 88             2    11.64        2.06  2.46  ...             2.80  1.000                          2.75      680
# 112            2    11.76        2.68  2.92  ...             3.80  1.230                          2.50      607
# 96             2    11.81        2.12  2.74  ...             2.50  0.950                          2.26      625
# 74             2    11.96        1.09  2.30  ...             3.21  0.990                          3.13      886
# 80             2    12.00        0.92  2.00  ...             2.50  1.380                          3.12      278
# 125            2    12.07        2.16  2.17  ...             2.76  0.860                          3.28      378
# 114            2    12.08        1.39  2.50  ...             2.90  0.930                          3.19      385
# 82             2    12.08        1.13  2.51  ...             2.20  1.310                          2.72      630
# 69             2    12.21        1.19  1.75  ...             2.85  1.280                          3.07      718
# 106            2    12.25        1.73  2.12  ...             3.40  1.000                          3.17      510
# 70             2    12.29        1.61  2.21  ...             3.05  0.906                          1.82      870
# 63             2    12.37        1.13  2.16  ...             4.45  1.220                          2.87      420
# 111            2    12.52        2.43  2.17  ...             2.00  0.900                          2.78      325
# 101            2    12.60        1.34  1.90  ...             2.45  1.040                          2.77      562
# 85             2    12.67        0.98  2.24  ...             2.62  1.230                          3.16      450
# 79             2    12.70        3.87  2.40  ...             2.57  1.190                          3.13      463
# 83             2    13.05        3.86  2.32  ...             4.80  0.840                          2.01      515
# 123            2    13.05        5.80  2.13  ...             2.60  0.730                          3.10      380
# 71             2    13.86        1.51  2.67  ...             3.38  1.360                          3.16      410
# 160            3    12.36        3.83  2.38  ...             7.65  0.560                          1.58      520
# 132            3    12.81        2.31  2.40  ...             5.70  0.660                          1.36      560
# 139            3    12.84        2.96  2.61  ...             4.92  0.890                          2.15      590
# 147            3    12.87        4.61  2.48  ...             7.65  0.540                          1.86      625
# 149            3    13.08        3.90  2.36  ...             9.40  0.570                          1.33      550
# 145            3    13.16        3.57  2.15  ...             4.00  0.600                          1.68      830
# 155            3    13.17        5.19  2.32  ...             7.90  0.600                          1.48      725
# 175            3    13.27        4.28  2.26  ...            10.20  0.590                          1.56      835
# 141            3    13.36        2.56  2.35  ...             5.60  0.700                          2.47      780
# 159            3    13.48        1.67  2.64  ...            11.75  0.570                          1.78      620
# 142            3    13.52        3.17  2.72  ...             4.35  0.890                          2.06      520
# 168            3    13.58        2.58  2.69  ...             8.66  0.740                          1.80      750
# 143            3    13.62        4.95  2.35  ...             4.40  0.910                          2.05      550
# 165            3    13.73        4.36  2.26  ...             6.62  0.780                          1.75      520
# 172            3    14.16        2.51  2.48  ...             9.70  0.620                          1.71      660
#
# [53 rows x 14 columns]

# %%
Train_set = df_wine.sample(frac = 0.7)
Train_set = Train_set.sort_values(by = ['Class label', 'Ash'])
print(Train_set)
# Out:
#      Class label  Alcohol  Malic acid   Ash  ...  Color intensity   Hue  OD280/OD315 of diluted wines  Proline
# 50             1    13.05        1.73  2.04  ...             7.20  1.12                          2.91     1150
# 38             1    13.07        1.50  2.10  ...             3.70  1.18                          2.69     1020
# 44             1    13.05        1.77  2.10  ...             5.04  0.88                          3.35      885
# 47             1    13.90        1.68  2.12  ...             6.10  0.91                          3.33      985
# 8              1    14.83        1.64  2.17  ...             5.20  1.08                          2.85     1045
# ..           ...      ...         ...   ...  ...              ...   ...                           ...      ...
# 168            3    13.58        2.58  2.69  ...             8.66  0.74                          1.80      750
# 158            3    14.34        1.68  2.70  ...            13.00  0.57                          1.96      660
# 140            3    12.93        2.81  2.70  ...             4.60  0.77                          2.31      600
# 177            3    14.13        4.10  2.74  ...             9.20  0.61                          1.60      560
# 169            3    13.40        4.60  2.86  ...             8.50  0.67                          1.92      630
#
# [125 rows x 14 columns]
